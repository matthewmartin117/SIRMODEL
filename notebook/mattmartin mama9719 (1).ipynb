# %%
import numpy as np
import numpy.linalg as npl
import math
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %% [markdown]
# # 9.3 Epidemic Dynamics

# %% [markdown]
# **Simple SIR Model - Activity ONE**

# %%
#Use Pseudocode from Calculus in Context, Chapter 2 page 69 to plot the 3 functions S, I and R. Use a (.00001)and b (14) as varibles instead of numbers
#Use a fixed plot window with y as the total height and fix the number of days you want to explore.
# Set parameters
a = 0.00001  # Infection rate
b = 14  # Recovery rate
death_rate = 0.1  # 10% of recovered cases lead to death

# Initial conditions
t_initial = 0
t_final = 30  # Time in days
t = t_initial
S = 45400
I = 2100
R = 2500
D = 0  # Initial deaths
number_of_steps = 30
delta_t = (t_final - t_initial) / number_of_steps

# Total population for fixed plot window
total_population = S + I + R

# Lists to store the values for plotting
t_values = [t]
S_values = [S]
I_values = [I]
R_values = [R]
D_values = [D]

# Simulation loop
for k in range(1, number_of_steps + 1):
    # Calculate rate of change
    S_prime = -a * S * I
    I_prime = a * S * I - I / b
    R_prime = (1 - death_rate) * I / b
    D_prime = death_rate * I / b
    
    # Calculate the changes
    delta_S = S_prime * delta_t
    delta_I = I_prime * delta_t
    delta_R = R_prime * delta_t
    delta_D = D_prime * delta_t
    
    # Update the variables
    t = t + delta_t
    S = S + delta_S
    I = I + delta_I
    R = R + delta_R
    D = D + delta_D
    
    # Store the values
    t_values.append(t)
    S_values.append(S)
    I_values.append(I)
    R_values.append(R)
    D_values.append(D)

# Plotting the results
plt.plot(t_values, S_values, label="Susceptible")
plt.plot(t_values, I_values, label="Infected")
plt.plot(t_values, R_values, label="Recovered")
plt.plot(t_values, D_values, label="Deaths")

# Setting a fixed y-axis for better comparison
plt.ylim(0, total_population)

# Add labels and title
plt.xlabel('Time (days)')
plt.ylabel('Population')
plt.title('SIRD Model Simulation')


plt.legend()

# Show the plot
plt.show()


#Shortest Mathplotlib tutorial ever.
#Just use this - you need to arrange the data each time as below - but really you don't need all the bells and whistles.

import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [1, 9, 3, 1])

plt.plot([1, 2, 3, 4], [16, 7, 5, 2])

plt.plot([1,2, 3, 4], [1, 2, 4, 4])

# %% [markdown]
# **Question 1:**
# Test your model with a = .00001 and b = 10 over 50 days and check with the given textbook. Show the output. Provide simple context for this model with comments or text.

# %%
# Set parameters
a = 0.00001  # Infection rate
b = 10  # Recovery rate
death_rate = 0.1  # 10% of recovered cases lead to death

# Initial conditions
t_initial = 0
t_final = 50  # Time in days
t = t_initial
S = 45400
I = 2100
R = 2500
D = 0  # Initial deaths
number_of_steps = 30
delta_t = (t_final - t_initial) / number_of_steps

# Total population for fixed plot window
total_population = S + I + R

# Lists to store the values for plotting
t_values = [t]
S_values = [S]
I_values = [I]
R_values = [R]
D_values = [D]

# Simulation loop
for k in range(1, number_of_steps + 1):
    # Calculate rate of change
    S_prime = -a * S * I
    I_prime = a * S * I - I / b
    R_prime = (1 - death_rate) * I / b
    D_prime = death_rate * I / b
    
    # Calculate the changes
    delta_S = S_prime * delta_t
    delta_I = I_prime * delta_t
    delta_R = R_prime * delta_t
    delta_D = D_prime * delta_t
    
    # Update the variables
    t = t + delta_t
    S = S + delta_S
    I = I + delta_I
    R = R + delta_R
    D = D + delta_D
    
    # Store the values
    t_values.append(t)
    S_values.append(S)
    I_values.append(I)
    R_values.append(R)
    D_values.append(D)

# Plotting the results using a simple approach
plt.plot(t_values, S_values, label="Susceptible")
plt.plot(t_values, I_values, label="Infected")
plt.plot(t_values, R_values, label="Recovered")
plt.plot(t_values, D_values, label="Deaths")

# Setting a fixed y-axis for better comparison
plt.ylim(0, total_population)

# Adding labels and title
plt.xlabel('Time (days)')
plt.ylabel('Population')
plt.title('SIRD Model Simulation')

# Adding a legend to differentiate the lines
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# This model shows the SIRD model simulation with the rate of infections per contact (a) being .00001 and num of days to recover  (b) = 10 over the course of 50 days. the death rate is set at about 10% so 10 percent of those infected die. The infected peak at about 12-15 days, it takes about 30 days for most of the population to recover.

# %% [markdown]
# **Question 2:** Using your SIRPLOT code above, explore what happens when you change the length of time a disease takes to recover (which may happen with a new medicine for example). Provide examples from your model in code blocks and context and explanation in textblocks.

# %%
# Set parameters
a = 0.00001  # Infection rate
b = 3  # New mediccine causes the recovery rate to be reduce to a fourth of what it originally was
death_rate = 0.1  # 10% of recovered cases lead to death

# Initial conditions
t_initial = 0
t_final = 50  # Time in days
t = t_initial
S = 45400
I = 2100
R = 2500
D = 0  # Initial deaths
number_of_steps = 30
delta_t = (t_final - t_initial) / number_of_steps

# Total population for fixed plot window
total_population = S + I + R

# Lists to store the values for plotting
t_values = [t]
S_values = [S]
I_values = [I]
R_values = [R]
D_values = [D]

# Simulation loop
for k in range(1, number_of_steps + 1):
    # Calculate rate of change
    S_prime = -a * S * I
    I_prime = a * S * I - I / b
    R_prime = (1 - death_rate) * I / b
    D_prime = death_rate * I / b
    
    # Calculate the changes
    delta_S = S_prime * delta_t
    delta_I = I_prime * delta_t
    delta_R = R_prime * delta_t
    delta_D = D_prime * delta_t
    
    # Update the variables
    t = t + delta_t
    S = S + delta_S
    I = I + delta_I
    R = R + delta_R
    D = D + delta_D
    
    # Store the values
    t_values.append(t)
    S_values.append(S)
    I_values.append(I)
    R_values.append(R)
    D_values.append(D)

# Plotting the results using a simple approach
plt.plot(t_values, S_values, label="Susceptible")
plt.plot(t_values, I_values, label="Infected")
plt.plot(t_values, R_values, label="Recovered")
plt.plot(t_values, D_values, label="Deaths")

# Setting a fixed y-axis for better comparison
plt.ylim(0, total_population)

# Adding labels and title
plt.xlabel('Time (days)')
plt.ylabel('Population')
plt.title('SIRD Model Simulation')

# Adding a legend to differentiate the lines
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# When a novel medicine is released and used that would hypothetically reduce the recovery time required for a person contracting the epidemic , the rate of infection is drastically lowered, the disease affects less of the susceptible population , and there is no peak in the infected ; "peak is flattened".

# %% [markdown]
# **Question 3:** Using your SIRPLOT code above, explore what happens to the course of a disease when you change the transmission coeffient a (which happens if people self-isolate for example). Provide examples from your model in code blocks and context and explanation in textblocks.

# %%
# Set parameters
a = 0.0000025  # Infection rate
b = 10  # Recovery rate
death_rate = 0.1  # 10% of recovered cases lead to death

# Initial conditions
t_initial = 0
t_final = 50  # Time in days
t = t_initial
S = 45400
I = 2100
R = 2500
D = 0  # Initial deaths
number_of_steps = 30
delta_t = (t_final - t_initial) / number_of_steps

# Total population for fixed plot window
total_population = S + I + R

# Lists to store the values for plotting
t_values = [t]
S_values = [S]
I_values = [I]
R_values = [R]
D_values = [D]

# Simulation loop
for k in range(1, number_of_steps + 1):
    # Calculate rate of change
    S_prime = -a * S * I
    I_prime = a * S * I - I / b
    R_prime = (1 - death_rate) * I / b
    D_prime = death_rate * I / b
    
    # Calculate the changes
    delta_S = S_prime * delta_t
    delta_I = I_prime * delta_t
    delta_R = R_prime * delta_t
    delta_D = D_prime * delta_t
    
    # Update the variables
    t = t + delta_t
    S = S + delta_S
    I = I + delta_I
    R = R + delta_R
    D = D + delta_D
    
    # Store the values
    t_values.append(t)
    S_values.append(S)
    I_values.append(I)
    R_values.append(R)
    D_values.append(D)

# Plotting the results using a simple approach
plt.plot(t_values, S_values, label="Susceptible")
plt.plot(t_values, I_values, label="Infected")
plt.plot(t_values, R_values, label="Recovered")
plt.plot(t_values, D_values, label="Deaths")

# Setting a fixed y-axis for better comparison
plt.ylim(0, total_population)

# Adding labels and title
plt.xlabel('Time (days)')
plt.ylabel('Population')
plt.title('SIRD Model Simulation')

# Adding a legend to differentiate the lines
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# if the infection rate is reduced by self isolating , for example from a = 0.00001  to a = 0.0000025 , the num of infected decreases instead of displaying any type of peak , and the recovery , infected, and susceptible are all affected linearly.

# %% [markdown]
# **SIR with Differential Equations**

# %% [markdown]
# **Question 4:**
# Look at the following implementation of SIR (adapted from the https://scipython.com/book/chapter-8-scipy/additional-examples/the-sir-epidemic-model/) using differential equations.
#
# How is it the same and how is it different to SIRPLOT? Answer here with code and text examples.
#
# This is similar to SIRPLOT in the model structure , it still uses Sucesvtbile , infected, and recrovered, as well as the parameteres, there are just different names for the vars,infection rate 'a' is 'beta' and recovery rate 'b' is 'gamma'. Both show changes in S I R over time. One of the differences in the code is the I is set to just one infected individual intially. The total population is also smaller. The deathrate is different , only 1% opposed to 10%. The days are alos
# longer at 160 days.
#
#
# Total population, N.
#
# N = 1000
#
#  Initial number of infected and recovered individuals, I0 and R0.
#
# I0, R0 = 1,
#
# The second model also used odeint as well, and uses integration
#
#  Integrate the SIR equations over the time grid, t.
#
# ret = odeint(deriv, y0, t, args=(N, beta, gamma))
#
# S, I, R = ret.T
#
# The second model uses a time grid and integrates the equations across the grid.
#
#  A grid of time points (in days)
#
# t = np.linspace(0, 160, 160)
#
#
#
#
# **Question 5:**
# Can you use this model to explore the Questions 2 and 3 above. Answer here.
#
# You can use this model to explore questions 2 adnd 3, I copied the code into the cell below and altered beta in order to see the effect of reducing the contact rate, and gamma to reduce the length of recovery.

# %%
#Using Differential Equations


# Total population, N.
N = 1000

timeperiod =160
# Initial number of infected and recovered individuals, I0 and R0.
I0=1
R0 =1
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - R0

D0 =0


#TRY modifying a and b

# Contact rate, a, and mean recovery rate, b, (in 1/days).

days=5 #(days to recover - how long are the infected able to pass it on )

a=.00025 #(more contact, how quickly it spreads)

b=1/days 

deathrate = .01
recover = 1 - deathrate





# A grid of time points (in days)
t = np.linspace(0, 160, timeperiod)

# The SIR model differential equations.
def deriv(y, t, N, a, b):
    S, I, R, D = y
    dSdt = -a * S * I 
    dIdt = a * S * I  - b * I
    dRdt = recover * (b * I)
    dDrt = deathrate * (b * I) 
    return dSdt, dIdt, dRdt, dDrt

# Initial conditions vector
y0 = S0, I0, R0, D0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(N, a, b))
S, I, R, D = ret.T

# Plot the data on three separate curves for S(t), I(t) and R(t)
fig = plt.figure(facecolor='w')
#ax = fig.add_subplot(111, axis_bgcolor='#dddddd', axisbelow=True)
ax = fig.add_subplot(111, axisbelow=True)
ax.plot(t, S/1000, 'b', alpha=0.5, lw=2, label='Susceptible')
ax.plot(t, I/1000, 'r', alpha=0.5, lw=2, label='Infected')
ax.plot(t, R/1000, 'g', alpha=0.5, lw=2, label='Recovered with immunity')
ax.plot(t, D/1000, 'y', alpha=0.5, lw=2, label='died')
ax.set_xlabel('Time /days')
ax.set_ylabel('Number (1000s)')
ax.set_ylim(0,1.2)
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 65
#      63 ax.yaxis.set_tick_params(length=0)
#      64 ax.xaxis.set_tick_params(length=0)
# ---> 65 ax.grid(b=True, which='major', c='w', lw=2, ls='-')
#      66 legend = ax.legend()
#      67 legend.get_frame().set_alpha(0.5)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/axes/_base.py:3194, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3192 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3193 if axis in ['x', 'both']:
# -> 3194     self.xaxis.grid(visible, which=which, **kwargs)
#    3195 if axis in ['y', 'both']:
#    3196     self.yaxis.grid(visible, which=which, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/axis.py:1660, in Axis.grid(self, visible, which, **kwargs)
#    1657 if which in ['major', 'both']:
# ...

# %% [markdown]
# **SIR with Matrices**
#
# **Question 6:**
# How is this implementation the same and different than SIRPLOT and the differential equation SIRmodel? Can you explore changes in the transmission coefficent and recovery rate the same way? Answer here.
#
# This implementation is different from SIRPLOT And differential equation SIR model because it uses 200 day timepsan in its model, it also goes into more detail about immunity and recovery, where some of  those infected will recover with no immunity which is allows them to get reinfected, while others will recover with immunity. The death rate from the disease is the same as the differential SIRModel. They are differer because the equation is applied in terms of matrix multiplication.
#
# **Question 7:**
# What are the advantages and disadvantages of this matrix model?  Answer here.
#
# The siimoplicity of the matrix model is straightfowaord , and it uses lin alg to simulate the model using matrix multiplication. Matrix operations are quick when it comes to mathmatical operations, The matrix model can also be modified to include different conditions to more accurately display the data , for example adding a "vaccinated"  state in order to make an even more accurate model approximation. The disadvantage of this model and the other models is it does not account for randomness, and the more complex aspects of disease transmision. immunity development rate could increase or decrease, not remain static

# %%
T  = 210 #number of days
a= .05         # % new infection each day
aS= 1 - a      # % remain suseptible
rnI= .04       # recover no immunity
rI= .1         # recover with immunity
rD= .01        # die from disease


A = np.matrix([[aS,rnI,0,0],[rnI+rD,(1-(rnI +rI + rD)) ,0,0],[0,rI,1,0],[0,rD,0,1]]) #dynamics matrix
x1 = np.array([1,0,0,0]) #initial state: everyone healthy
stateTraj = np.hstack([np.vstack(x1),np.zeros((4,T-1))]) #initialize trajectory with 0s
for t in range(T-1):
    stateTraj[:,t+1] = np.matmul(A,stateTraj[:,t])

for i in range(len(stateTraj)):
    plt.plot(range(T),stateTraj[i])

plt.legend(["Susceptible","Infected","Recovered","Deceased"])

# %% [markdown]
# (Want more? Check out Chapters 4 and 8 from Calculus in Context.)
